# %% [markdown]
# # NBA 2024-25: Slump Shots & Recovery Shots
# ## Notebook 03: Slump & Recovery Detection
# This notebook implements the core analytical logic of the study: identifying shooting slumps and recoveries at the player-game level.
#
# Using rolling shot windows, each shot is classified into one of three states:
# - neutral
# - slump
# - recovered

# %%
# Import libraries
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Display options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
pd.set_option("display.width", 160)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: f"{x:.2f}")

# %% [markdown]
# ---
# ## Load Data

# %%
# Load cleaned shot-level data from 2024-25 regular season
shots = pd.read_parquet(r"C:\Users\dylan\OneDrive\Documents\Portfolio_Projects\NBA_2024_25_shot_level\03_python_outputs\nba_2024_25_shot_level_data_clean.parquet")

# %%
# Inspect structure
shots.head(10)
# Out:
#     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME     TEAM_ID       TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING                     ACTION_TYPE  \
# 0  22400001            288     201143    Al Horford  1610612738  Boston Celtics       2                  4                 29                       Jump Shot
# 1  22400001            299     201143    Al Horford  1610612738  Boston Celtics       2                  3                 47                       Jump Shot
# 2  22400001            372     201143    Al Horford  1610612738  Boston Celtics       3                 10                 41                       Jump Shot
# 3  22400001            399     201143    Al Horford  1610612738  Boston Celtics       3                  8                  2                       Jump Shot
# 4  22400001            409     201143    Al Horford  1610612738  Boston Celtics       3                  6                 43  Running Finger Roll Layup Shot
# 5  22400001            217     201950  Jrue Holiday  1610612738  Boston Celtics       2                  9                  0                Pullup Jump shot
# 6  22400001            226     201950  Jrue Holiday  1610612738  Boston Celtics       2                  8                  4              Driving Layup Shot
# 7  22400001            244     201950  Jrue Holiday  1610612738  Boston Celtics       2                  6                 50       Running Pull-Up Jump Shot
# 8  22400001            364     201950  Jrue Holiday  1610612738  Boston Celtics       3                 11                 43              Floating Jump shot
# 9  22400001            446     201950  Jrue Holiday  1610612738  Boston Celtics       3                  4                 13                Pullup Jump shot
#
#         SHOT_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM  calc_dist
# 0  3PT Field Goal      Above the Break 3   Left Side Center(LC)          24+ ft.             26   -103    247               1 2024-11-12  BOS  ATL     267.62
# 1  3PT Field Goal      Above the Break 3              Center(C)          24+ ft.             29    -69    289               1 2024-11-12  BOS  ATL     297.12
# 2  3PT Field Goal      Above the Break 3   Left Side Center(LC)          24+ ft.             24   -172    180               0 2024-11-12  BOS  ATL     248.97
# 3  3PT Field Goal      Above the Break 3  Right Side Center(RC)          24+ ft.             26    102    241               0 2024-11-12  BOS  ATL     261.70
# 4  2PT Field Goal        Restricted Area              Center(C)  Less Than 8 ft.              1     13      6               1 2024-11-12  BOS  ATL      14.32
# 5  3PT Field Goal      Above the Break 3   Left Side Center(LC)          24+ ft.             26    -94    249               0 2024-11-12  BOS  ATL     266.15
# 6  2PT Field Goal        Restricted Area              Center(C)  Less Than 8 ft.              2     25     13               1 2024-11-12  BOS  ATL      28.18
# 7  3PT Field Goal      Above the Break 3              Center(C)          24+ ft.             27    -54    265               0 2024-11-12  BOS  ATL     270.45
# 8  2PT Field Goal  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.              6     36     49               1 2024-11-12  BOS  ATL      60.80
# 9  3PT Field Goal      Above the Break 3  Right Side Center(RC)          24+ ft.             24    129    210               0 2024-11-12  BOS  ATL     246.46

# %%
# Inspect columns
shots.columns
# Out:
# Index(['GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'ACTION_TYPE',
#        'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM',
#        'calc_dist'],
#       dtype='object')

# %%
# Number of unique players
shots["PLAYER_NAME"].nunique()
# Out:
# 566

# %% [markdown]
# ---
# ## Slump & Recovery Detection

# %%
# Create shot index (shot 1, shot 2, ..., shot n)
shots["shot_idx"] = shots.groupby(["GAME_ID", "PLAYER_ID"]).cumcount() + 1

# %%
# --- Detect "slump" and "recovery" (one player-game at a time) ---
def detect_slump_and_recovery(player_game_shots):
    """
    Labels each shot in a single player-game sequence as:
    - "neutral"   : default shooting state
    - "slump"     : shots taken while in a slump
    - "recovered" : the single shot that signals a recovery

    Rules:
    - A slump triggers after:
        • 0 made shots in the previous 3 attempts
    - All subsequent shots are slump shots until a recovery occurs.
    - A recovery triggers after:
        • 2 consecutive made shots, or
        • 2 made shots in the previous 3 attempts
    - In all other cases, the default state is "neutral"
    """
    df = player_game_shots.copy()   # each temporary DataFrame is one player's shots from one game
    df["phase"] = "neutral"   # default value
    
    shot_outcomes = df["SHOT_MADE_FLAG"].values
    n = len(df)   # total number of shots in the player-game
    phase_col = df.columns.get_loc("phase")

    state = "neutral"   # default state
    neutral_start_idx = 0   # current neutral streak begins
    recovery_window = []

    for i in range(n):   # i is the current shot
        # -----------------------------
        # IN NEUTRAL → CHECK FOR SLUMP
        # -----------------------------
        if state == "neutral":

            neutral_len = i - neutral_start_idx + 1   # how many shots in current neutral streak
            slump_triggered = False

            # Slump Condition A: 0-for-3
            if neutral_len >= 3:   # first 2 shots of every player-game will always be neutral
                if shot_outcomes[i-2:i+1].sum() == 0:   # previous 3 shots including current shot
                    slump_triggered = True

            if slump_triggered:
                df.iloc[i, phase_col] = "slump"
                state = "slump"
                recovery_window = []
            else:
                df.iloc[i, phase_col] = "neutral"

        # -----------------------------
        # IN SLUMP → CHECK FOR RECOVERY
        # -----------------------------
        else:
            df.iloc[i, phase_col] = "slump"

            # Track only last 3 shots
            recovery_window.append(shot_outcomes[i])   # append the current shot outcome to the recovery window
            if len(recovery_window) > 3:
                recovery_window.pop(0)   # only keep last 3 shots in recovery window  ("pop" the 0th index)

            # Recovery Condition A: 2-for-2
            if len(recovery_window) >= 2 and sum(recovery_window[-2:]) == 2:   # 2 makes in last 2 shots
                df.iloc[i, phase_col] = "recovered"
                state = "neutral"
                neutral_start_idx = i + 1   # the next shot returns to neutral state
                recovery_window = []

            # Recovery Condition B: 2-for-3
            if len(recovery_window) == 3 and sum(recovery_window) == 2:   # 2 makes in last 3 shots
                df.iloc[i, phase_col] = "recovered"
                state = "neutral"
                neutral_start_idx = i + 1   # the next shot returns to neutral state
                recovery_window = []

        # note: an "unrecovered" slump at the end of a game always resets to neutral at the start of a new game (i.e., slumps do not carry over game to game)
    return df

# %% [markdown]
# ## 🔑
# > This state logic is the most important cell of the study. Once implemented in the next cell, **every single shot attempt** will have a state (or phase) label now, from which analytical insights can be found (in Notebook 04).

# %%
# --- Apply this state logic to all player-game rows ---
tqdm.pandas(desc="Processing player-games")

shots = shots.groupby(["GAME_ID", "PLAYER_ID"], group_keys=False).progress_apply(detect_slump_and_recovery)
# Out:
# Processing player-games: 100%|██████████| 24835/24835 [01:21<00:00, 303.05it/s]

# %%
# --- Test one game from one player ---
test = shots[shots["PLAYER_NAME"] == "Jayson Tatum"]

test[["PLAYER_NAME", "SHOT_MADE_FLAG", "shot_idx", "phase"]].head(500)
# Out:
#         PLAYER_NAME  SHOT_MADE_FLAG  shot_idx      phase
# 53     Jayson Tatum               0         1    neutral
# 54     Jayson Tatum               0         2    neutral
# 55     Jayson Tatum               0         3      slump
# 56     Jayson Tatum               0         4      slump
# 57     Jayson Tatum               1         5      slump
# 58     Jayson Tatum               1         6  recovered
# 59     Jayson Tatum               0         7    neutral
# 60     Jayson Tatum               1         8    neutral
# 61     Jayson Tatum               0         9    neutral
# 62     Jayson Tatum               1        10    neutral
# 63     Jayson Tatum               1        11    neutral
# 64     Jayson Tatum               0        12    neutral
# 65     Jayson Tatum               0        13    neutral
# 66     Jayson Tatum               0        14      slump
# 67     Jayson Tatum               0        15      slump
# 68     Jayson Tatum               0        16      slump
# 3623   Jayson Tatum               0         1    neutral
# 3624   Jayson Tatum               1         2    neutral
# 3625   Jayson Tatum               1         3    neutral
# 3626   Jayson Tatum               0         4    neutral
# 3627   Jayson Tatum               1         5    neutral
# 3628   Jayson Tatum               0         6    neutral
# 3629   Jayson Tatum               1         7    neutral
# 3630   Jayson Tatum               1         8    neutral
# 3631   Jayson Tatum               0         9    neutral
# 3632   Jayson Tatum               1        10    neutral
# 3633   Jayson Tatum               0        11    neutral
# 3634   Jayson Tatum               1        12    neutral
# 3635   Jayson Tatum               0        13    neutral
# 3636   Jayson Tatum               0        14    neutral
# 3637   Jayson Tatum               0        15      slump
# 3638   Jayson Tatum               1        16      slump
# 3639   Jayson Tatum               1        17  recovered
# 3640   Jayson Tatum               1        18    neutral
# 3641   Jayson Tatum               0        19    neutral
# 3642   Jayson Tatum               0        20    neutral
# 3643   Jayson Tatum               1        21    neutral
# 3644   Jayson Tatum               0        22    neutral
# 4875   Jayson Tatum               1         1    neutral
# 4876   Jayson Tatum               0         2    neutral
# 4877   Jayson Tatum               0         3    neutral
# 4878   Jayson Tatum               0         4      slump
# 4879   Jayson Tatum               0         5      slump
# 4880   Jayson Tatum               0         6      slump
# 4881   Jayson Tatum               1         7      slump
# 4882   Jayson Tatum               0         8      slump
# 4883   Jayson Tatum               0         9      slump
# 4884   Jayson Tatum               0        10      slump
# 4885   Jayson Tatum               0        11      slump
# 4886   Jayson Tatum               1        12      slump
# 4887   Jayson Tatum               0        13      slump
# 4888   Jayson Tatum               0        14      slump
# 4889   Jayson Tatum               0        15      slump
# 4890   Jayson Tatum               1        16      slump
# 4891   Jayson Tatum               1        17  recovered
# 4892   Jayson Tatum               1        18    neutral
# 4893   Jayson Tatum               0        19    neutral
# 8275   Jayson Tatum               0         1    neutral
# 8276   Jayson Tatum               0         2    neutral
# 8277   Jayson Tatum               1         3    neutral
# 8278   Jayson Tatum               0         4    neutral
# 8279   Jayson Tatum               1         5    neutral
# 8280   Jayson Tatum               1         6    neutral
# 24856  Jayson Tatum               0        13      slump
# 24857  Jayson Tatum               0        14      slump
# 24858  Jayson Tatum               1        15      slump
# 27707  Jayson Tatum               1         1    neutral
# 27708  Jayson Tatum               1         2    neutral
# 27709  Jayson Tatum               1         3    neutral
# 27710  Jayson Tatum               0         4    neutral
# 27711  Jayson Tatum               1         5    neutral
# 27712  Jayson Tatum               1         6    neutral
# 27713  Jayson Tatum               0         7    neutral
# 27714  Jayson Tatum               1         8    neutral
# 27715  Jayson Tatum               1         9    neutral
# 27716  Jayson Tatum               1        10    neutral
# 27717  Jayson Tatum               0        11    neutral
# 27718  Jayson Tatum               1        12    neutral
# 27719  Jayson Tatum               0        13    neutral
# 27720  Jayson Tatum               0        14    neutral
# 27721  Jayson Tatum               0        15      slump
# 27722  Jayson Tatum               0        16      slump
# 27723  Jayson Tatum               0        17      slump
# 27724  Jayson Tatum               1        18      slump
# 27725  Jayson Tatum               0        19      slump
# 27726  Jayson Tatum               0        20      slump
# 27727  Jayson Tatum               0        21      slump
# 30414  Jayson Tatum               0         1    neutral
# 30415  Jayson Tatum               0         2    neutral
# 30416  Jayson Tatum               0         3      slump
# 30417  Jayson Tatum               0         4      slump
# 30418  Jayson Tatum               1         5      slump
# 30419  Jayson Tatum               1         6  recovered
# 30420  Jayson Tatum               0         7    neutral
# 30421  Jayson Tatum               1         8    neutral
# 30422  Jayson Tatum               1         9    neutral
# 30423  Jayson Tatum               1        10    neutral
# 30424  Jayson Tatum               1        11    neutral
# 30425  Jayson Tatum               0        12    neutral
# 30426  Jayson Tatum               1        13    neutral
# 30427  Jayson Tatum               0        14    neutral
# 30428  Jayson Tatum               0        15    neutral
# 30429  Jayson Tatum               1        16    neutral
# 30430  Jayson Tatum               1        17    neutral
# 30431  Jayson Tatum               0        18    neutral
# 30432  Jayson Tatum               1        19    neutral
# 30433  Jayson Tatum               0        20    neutral
# 33020  Jayson Tatum               0         1    neutral
# 33021  Jayson Tatum               1         2    neutral
# 33022  Jayson Tatum               0         3    neutral
# 33023  Jayson Tatum               0         4    neutral
# 33024  Jayson Tatum               1         5    neutral
# 33025  Jayson Tatum               1         6    neutral
# 33026  Jayson Tatum               1         7    neutral
# 33027  Jayson Tatum               0         8    neutral
# 33028  Jayson Tatum               0         9    neutral
# 33029  Jayson Tatum               0        10      slump
# 33030  Jayson Tatum               0        11      slump
# 33031  Jayson Tatum               0        12      slump
# 33032  Jayson Tatum               1        13      slump
# 33033  Jayson Tatum               0        14      slump
# 33034  Jayson Tatum               0        15      slump
# 33035  Jayson Tatum               1        16      slump
# 33036  Jayson Tatum               1        17  recovered
# 33037  Jayson Tatum               1        18    neutral
# 33038  Jayson Tatum               0        19    neutral
# 33039  Jayson Tatum               1        20    neutral
# 33040  Jayson Tatum               0        21    neutral
# 33041  Jayson Tatum               1        22    neutral
# 33042  Jayson Tatum               0        23    neutral
# 33043  Jayson Tatum               1        24    neutral
# 33044  Jayson Tatum               0        25    neutral
# 35693  Jayson Tatum               0         1    neutral
# 35694  Jayson Tatum               0         2    neutral
# 35695  Jayson Tatum               1         3    neutral
# 35696  Jayson Tatum               0         4    neutral
# 35697  Jayson Tatum               0         5    neutral
# 35698  Jayson Tatum               0         6      slump
# 35699  Jayson Tatum               1         7      slump
# 35700  Jayson Tatum               1         8  recovered
# 35701  Jayson Tatum               1         9    neutral
# 35702  Jayson Tatum               0        10    neutral
# 35703  Jayson Tatum               0        11    neutral
# 35704  Jayson Tatum               0        12      slump
# 35705  Jayson Tatum               0        13      slump
# 35706  Jayson Tatum               1        14      slump
# 35707  Jayson Tatum               0        15      slump
# 35708  Jayson Tatum               0        16      slump
# 35709  Jayson Tatum               0        17      slump
# 35710  Jayson Tatum               1        18      slump
# 35711  Jayson Tatum               1        19  recovered
# 35712  Jayson Tatum               0        20    neutral
# 35713  Jayson Tatum               0        21    neutral
# 38450  Jayson Tatum               1         1    neutral
# 38451  Jayson Tatum               0         2    neutral
# 38452  Jayson Tatum               0         3    neutral
# 38453  Jayson Tatum               1         4    neutral
# 38454  Jayson Tatum               1         5    neutral
# 38455  Jayson Tatum               1         6    neutral
# 38456  Jayson Tatum               1         7    neutral
# 38457  Jayson Tatum               0         8    neutral
# 38458  Jayson Tatum               1         9    neutral
# 38459  Jayson Tatum               0        10    neutral
# 38460  Jayson Tatum               0        11    neutral
# 38461  Jayson Tatum               1        12    neutral
# 38462  Jayson Tatum               1        13    neutral
# 38463  Jayson Tatum               1        14    neutral
# 38464  Jayson Tatum               0        15    neutral
# 38465  Jayson Tatum               0        16    neutral
# 38466  Jayson Tatum               1        17    neutral
# 38467  Jayson Tatum               1        18    neutral
# 38468  Jayson Tatum               1        19    neutral
# 40611  Jayson Tatum               0         1    neutral
# 40612  Jayson Tatum               1         2    neutral
# 40613  Jayson Tatum               0         3    neutral
# 40614  Jayson Tatum               1         4    neutral
# 40615  Jayson Tatum               1         5    neutral
# 40616  Jayson Tatum               1         6    neutral
# 40617  Jayson Tatum               0         7    neutral
# 40618  Jayson Tatum               1         8    neutral
# 40619  Jayson Tatum               0         9    neutral
# 40620  Jayson Tatum               0        10    neutral
# 40621  Jayson Tatum               0        11      slump
# 40622  Jayson Tatum               0        12      slump
# 40623  Jayson Tatum               0        13      slump
# 40624  Jayson Tatum               0        14      slump
# 40625  Jayson Tatum               0        15      slump
# 40626  Jayson Tatum               0        16      slump
# 40627  Jayson Tatum               1        17      slump
# 40628  Jayson Tatum               0        18      slump
# 40629  Jayson Tatum               1        19  recovered
# 47891  Jayson Tatum               0         1    neutral
# 47892  Jayson Tatum               0         2    neutral
# 47893  Jayson Tatum               1         3    neutral
# 47894  Jayson Tatum               0         4    neutral
# 47895  Jayson Tatum               0         5    neutral
# 47896  Jayson Tatum               1         6    neutral
# 47897  Jayson Tatum               0         7    neutral
# 47898  Jayson Tatum               1         8    neutral
# 47899  Jayson Tatum               0         9    neutral
# 47900  Jayson Tatum               0        10    neutral
# 47901  Jayson Tatum               1        11    neutral
# 47902  Jayson Tatum               1        12    neutral
# 47903  Jayson Tatum               1        13    neutral
# 47904  Jayson Tatum               1        14    neutral
# 47905  Jayson Tatum               0        15    neutral
# 47906  Jayson Tatum               0        16    neutral
# 47907  Jayson Tatum               0        17      slump
# 47908  Jayson Tatum               0        18      slump
# 47909  Jayson Tatum               0        19      slump
# 59322  Jayson Tatum               0        10      slump
# 59323  Jayson Tatum               1        11      slump
# 59324  Jayson Tatum               0        12      slump
# 59325  Jayson Tatum               1        13  recovered
# 59326  Jayson Tatum               1        14    neutral
# 59327  Jayson Tatum               0        15    neutral
# 59328  Jayson Tatum               1        16    neutral
# 59329  Jayson Tatum               1        17    neutral
# 59330  Jayson Tatum               1        18    neutral
# 59331  Jayson Tatum               1        19    neutral
# 59332  Jayson Tatum               1        20    neutral
# 61026  Jayson Tatum               0         1    neutral
# 61027  Jayson Tatum               1         2    neutral
# 61028  Jayson Tatum               0         3    neutral
# 61029  Jayson Tatum               0         4    neutral
# 61030  Jayson Tatum               0         5      slump
# 61031  Jayson Tatum               0         6      slump
# 61032  Jayson Tatum               0         7      slump
# 61033  Jayson Tatum               0         8      slump
# 61034  Jayson Tatum               1         9      slump
# 61035  Jayson Tatum               1        10  recovered
# 61036  Jayson Tatum               0        11    neutral
# 61037  Jayson Tatum               0        12    neutral
# 61038  Jayson Tatum               1        13    neutral
# 61039  Jayson Tatum               1        14    neutral
# 61040  Jayson Tatum               0        15    neutral
# 61041  Jayson Tatum               0        16    neutral
# 61042  Jayson Tatum               0        17      slump
# 61043  Jayson Tatum               0        18      slump
# 61044  Jayson Tatum               1        19      slump
# 61045  Jayson Tatum               0        20      slump
# 61046  Jayson Tatum               0        21      slump
# 64220  Jayson Tatum               1         1    neutral
# 64221  Jayson Tatum               0         2    neutral
# 64222  Jayson Tatum               1         3    neutral
# 64223  Jayson Tatum               0         4    neutral
# 64224  Jayson Tatum               0         5    neutral
# 64225  Jayson Tatum               0         6      slump
# 64226  Jayson Tatum               0         7      slump
# 64227  Jayson Tatum               1         8      slump
# 64228  Jayson Tatum               0         9      slump
# 64229  Jayson Tatum               1        10  recovered
# 64230  Jayson Tatum               0        11    neutral
# 64231  Jayson Tatum               1        12    neutral
# 64232  Jayson Tatum               1        13    neutral
# 64233  Jayson Tatum               0        14    neutral
# 64234  Jayson Tatum               1        15    neutral
# 64235  Jayson Tatum               0        16    neutral
# 64236  Jayson Tatum               0        17    neutral
# 64237  Jayson Tatum               1        18    neutral
# 64238  Jayson Tatum               1        19    neutral
# 64239  Jayson Tatum               0        20    neutral
# 64240  Jayson Tatum               1        21    neutral
# 64241  Jayson Tatum               0        22    neutral
# 67406  Jayson Tatum               1         1    neutral
# 67407  Jayson Tatum               0         2    neutral
# 67408  Jayson Tatum               0         3    neutral
# 67409  Jayson Tatum               0         4      slump
# 67410  Jayson Tatum               0         5      slump
# 67411  Jayson Tatum               1         6      slump
# 67412  Jayson Tatum               0         7      slump
# 67413  Jayson Tatum               1         8  recovered
# 67414  Jayson Tatum               1         9    neutral
# 67415  Jayson Tatum               0        10    neutral
# 67416  Jayson Tatum               1        11    neutral
# 67417  Jayson Tatum               1        12    neutral
# 67418  Jayson Tatum               1        13    neutral
# 67419  Jayson Tatum               1        14    neutral

# %% [markdown]
# > To verify this state logic, I manually scanned through the first 500 shots from Jayson Tatum's season. All of the logic works as intended. The data is now ready for analysis.

# %% [markdown]
# ---
# ## Save

# %%
# Save to parquet
shots.to_parquet("nba_2024_25_shot_level_data_final.parquet")
